# %% [markdown]
# # Overview
#
# This exercise demonstrates how TEMPO data can be used to track and assess ozone precursors and ozone formation potential, in support of assessing ozone exceedances.
#
# **Notebook Author / Affiliation**
#
# * Author: Carl Malings / NASA ARSET
# * This notebook is based on examples from the [ASDC Data and User Services Github](https://github.com/nasa/ASDC_Data_and_User_Services).

# %% [markdown]
# ## Package Installation and Setup
#
# *Instructions*
#
# * Run the cell below to install the non-standard packages required for this exercise.
#
# *NOTE: This also includes the pyrisg package, in addition to those used in previous exercises*

# %%
# !pip install --quiet harmony-py cartopy pyrsig
# Out:
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 47.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 11.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 64.2 MB/s eta 0:00:00
#   Building wheel for curlify (setup.py) ... done

# %% [markdown]
# *Instructions*
#
# * Run the code cell below to import the required packages.

# %%
# Downloading TEMPO data
import datetime as dt
import getpass
import os
from harmony import BBox, Client, Collection, Request
from harmony.config import Environment

# Opening TEMPO data files
import xarray as xr

# Creating graphics
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from xarray.plot.utils import label_from_attrs

# Downloading AirNow data
import pyrsig

# Working with data tables
import numpy as np
import pandas as pd

# %% [markdown]
# # Download TEMPO NO2 and HCHO Data
#
# The first part of this exercise will be to download the TEMPO NO2 and HCHO data for the region and time period of interest.
#
# *Instructions*
#
# * Run the cell below and enter your Earthdata credentials to prepare for data downloading

# %%
username = input("Username:")

harmony_client = Client(env=Environment.PROD, auth=(username, getpass.getpass()))
# Out:
# Username:kpistone88
# ··········

# %% [markdown]
# ## Get TEMPO Level-3 NO2 Data
#
# The below code is copied from previous examples of downloading TEMPO data. You will use it to download TEMPO Level-3 NO2 data for a region and time period of inerest.
#
# **Region of Interest**: Colorado Front Range (latitude 38 to 41, longitude -106 to -103)
#
# **Time of Interest**: July 27 to 31, 2024
#
# *Instructions*
#
# * Modify the code in the next cells to download the TEMPO Level-3 NO2 data product for the region and time period of interest.
#
# * Run the cells in sequence to download the desired TEMPO data.
#
# <details>
#
# *Hint*: You will need to modify the `RoI`, `Collection id`, `start` and `stop` times.
#
# *Hint*: Use [Earthdata Search](https://search.earthdata.nasa.gov/search) to get the Collection id.
#
# </details>

# %% [markdown]
# *Build the request*

# %%
# This list will save the bounding box limits for later use:
RoI = [-106, 38, -103, 41]

# Structure the request:
request_no2 = Request(
    collection=Collection(id='C2930763263-LARC_CLOUD'),
    temporal={
        'start': dt.datetime(2024, 7, 27, 7,0,0),
        'stop': dt.datetime(2024, 7, 31, 23, 0, 0)
    },
    spatial=BBox(RoI[0], RoI[1], RoI[2], RoI[3]),
)

# Check the request is valid:
request_no2.is_valid()
# Out:
# True

# %% [markdown]
# *Submit and monitor the request*

# %%
job_id_no2 = harmony_client.submit(request_no2)
print(f"jobID = {job_id_no2}")

harmony_client.wait_for_processing(job_id_no2, show_progress=True)
# Out:
# jobID = aa6b55b3-124a-4116-9bee-be49c711ca46
#  [ Processing: 100% ] |###################################################| [|]

# %% [markdown]
# *Download the results*

# %%
download_dir = os.path.expanduser("~/tempo_data_ozone_precursor_exercise")
os.makedirs(download_dir, exist_ok=True)

results_no2 = harmony_client.download_all(job_id_no2, directory=download_dir)
all_results_stored_no2 = [f.result() for f in results_no2]

print(f"Number of files: {len(all_results_stored_no2)}")
# Out:
# /root/tempo_data_ozone_precursor_exercise/106862791_TEMPO_NO2_L3_V03_20240727T103122Z_S001_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862792_TEMPO_NO2_L3_V03_20240727T111127Z_S002_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862793_TEMPO_NO2_L3_V03_20240727T115132Z_S003_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862808_TEMPO_NO2_L3_V03_20240728T103139Z_S001_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862807_TEMPO_NO2_L3_V03_20240728T005202Z_S017_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862794_TEMPO_NO2_L3_V03_20240727T123137Z_S004_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862804_TEMPO_NO2_L3_V03_20240727T225147Z_S014_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862796_TEMPO_NO2_L3_V03_20240727T135147Z_S006_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862803_TEMPO_NO2_L3_V03_20240727T215147Z_S013_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862811_TEMPO_NO2_L3_V03_20240728T123154Z_S004_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862806_TEMPO_NO2_L3_V03_20240728T001157Z_S016_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862797_TEMPO_NO2_L3_V03_20240727T145148Z_S007_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862802_TEMPO_NO2_L3_V03_20240727T205147Z_S012_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862801_TEMPO_NO2_L3_V03_20240727T195147Z_S011_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862810_TEMPO_NO2_L3_V03_20240728T115149Z_S003_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862805_TEMPO_NO2_L3_V03_20240727T233152Z_S015_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862813_TEMPO_NO2_L3_V03_20240728T135204Z_S006_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862822_TEMPO_NO2_L3_V03_20240728T225204Z_S015_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862824_TEMPO_NO2_L3_V03_20240729T001214Z_S017_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862795_TEMPO_NO2_L3_V03_20240727T131142Z_S005_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862798_TEMPO_NO2_L3_V03_20240727T171416Z_S008_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862799_TEMPO_NO2_L3_V03_20240727T175147Z_S009_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862823_TEMPO_NO2_L3_V03_20240728T233209Z_S016_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862809_TEMPO_NO2_L3_V03_20240728T111144Z_S002_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862816_TEMPO_NO2_L3_V03_20240728T165204Z_S009_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862818_TEMPO_NO2_L3_V03_20240728T185204Z_S011_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862812_TEMPO_NO2_L3_V03_20240728T131159Z_S005_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862819_TEMPO_NO2_L3_V03_20240728T195204Z_S012_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862826_TEMPO_NO2_L3_V03_20240729T103155Z_S001_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862842_TEMPO_NO2_L3_V03_20240730T001230Z_S017_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862827_TEMPO_NO2_L3_V03_20240729T111200Z_S002_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862814_TEMPO_NO2_L3_V03_20240728T145204Z_S007_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862820_TEMPO_NO2_L3_V03_20240728T205204Z_S013_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862834_TEMPO_NO2_L3_V03_20240729T165220Z_S009_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862829_TEMPO_NO2_L3_V03_20240729T123210Z_S004_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862800_TEMPO_NO2_L3_V03_20240727T185147Z_S010_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862828_TEMPO_NO2_L3_V03_20240729T115205Z_S003_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862830_TEMPO_NO2_L3_V03_20240729T131215Z_S005_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862841_TEMPO_NO2_L3_V03_20240729T233225Z_S016_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862831_TEMPO_NO2_L3_V03_20240729T135220Z_S006_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862843_TEMPO_NO2_L3_V03_20240730T005235Z_S018_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862837_TEMPO_NO2_L3_V03_20240729T195220Z_S012_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862844_TEMPO_NO2_L3_V03_20240730T103211Z_S001_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862817_TEMPO_NO2_L3_V03_20240728T175204Z_S010_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862825_TEMPO_NO2_L3_V03_20240729T005219Z_S018_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862840_TEMPO_NO2_L3_V03_20240729T225220Z_S015_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862836_TEMPO_NO2_L3_V03_20240729T185220Z_S011_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862832_TEMPO_NO2_L3_V03_20240729T145220Z_S007_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862815_TEMPO_NO2_L3_V03_20240728T155204Z_S008_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862845_TEMPO_NO2_L3_V03_20240730T111216Z_S002_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862846_TEMPO_NO2_L3_V03_20240730T115221Z_S003_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862848_TEMPO_NO2_L3_V03_20240730T131231Z_S005_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862851_TEMPO_NO2_L3_V03_20240730T155236Z_S008_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862849_TEMPO_NO2_L3_V03_20240730T135236Z_S006_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862850_TEMPO_NO2_L3_V03_20240730T145236Z_S007_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862853_TEMPO_NO2_L3_V03_20240730T175236Z_S010_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862833_TEMPO_NO2_L3_V03_20240729T155220Z_S008_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862821_TEMPO_NO2_L3_V03_20240728T215204Z_S014_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862847_TEMPO_NO2_L3_V03_20240730T123226Z_S004_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862839_TEMPO_NO2_L3_V03_20240729T215220Z_S014_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862856_TEMPO_NO2_L3_V03_20240730T205236Z_S013_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862854_TEMPO_NO2_L3_V03_20240730T185236Z_S011_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862855_TEMPO_NO2_L3_V03_20240730T195236Z_S012_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862838_TEMPO_NO2_L3_V03_20240729T205220Z_S013_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862852_TEMPO_NO2_L3_V03_20240730T165236Z_S009_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862835_TEMPO_NO2_L3_V03_20240729T175220Z_S010_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862858_TEMPO_NO2_L3_V03_20240731T103227Z_S001_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862859_TEMPO_NO2_L3_V03_20240731T111232Z_S002_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862857_TEMPO_NO2_L3_V03_20240731T010539Z_S014_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862861_TEMPO_NO2_L3_V03_20240731T123242Z_S004_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862860_TEMPO_NO2_L3_V03_20240731T115237Z_S003_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862869_TEMPO_NO2_L3_V03_20240731T215252Z_S014_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862870_TEMPO_NO2_L3_V03_20240731T225252Z_S015_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862862_TEMPO_NO2_L3_V03_20240731T131247Z_S005_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862867_TEMPO_NO2_L3_V03_20240731T195252Z_S012_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862864_TEMPO_NO2_L3_V03_20240731T165252Z_S009_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862865_TEMPO_NO2_L3_V03_20240731T175252Z_S010_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862863_TEMPO_NO2_L3_V03_20240731T135252Z_S006_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862866_TEMPO_NO2_L3_V03_20240731T185252Z_S011_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106862868_TEMPO_NO2_L3_V03_20240731T205252Z_S013_subsetted.nc4
# Number of files: 80

# %% [markdown]
# *Open the files and combine into a single Dataset*
#
# <details>
#
# Note that there is a slightly different structure to this code than seen in previous examples. The dictionary `variables_to_keep_and_rename` provides a complete list of the variables to keep and the new names they will be assigned. This makes it more straightforward to change what variables are kept, so that the same code can be re-used more easily for the other TEMPO products.
#
# </details>

# %%
# Define which variables to keep and rename:
variables_to_keep_and_rename = {'product/vertical_column_troposphere':'no2_vertical_column_troposphere',
                                'product/main_data_quality_flag':'no2_qc_flag',
                                'geolocation/solar_zenith_angle':'no2_sza',
                                'support_data/eff_cloud_fraction':'no2_cloud_fraction'
                                }

# Create a dictionary to store the data:
data_dictionary = {variable:[] for variable in variables_to_keep_and_rename.keys()}

# Loop through the result files:
for result_file in sorted(all_results_stored_no2):
    # Loop throuch variables:
    for variable in variables_to_keep_and_rename.keys():
        # For each file and variable, add the data from that file to the appropriate list in the dictionary:
        data_dictionary[variable] += [xr.open_datatree(result_file)[variable]]

# Concatenate each list into a Dataset along the time dimenion:
for variable in variables_to_keep_and_rename.keys():
    data_dictionary[variable] = xr.concat(data_dictionary[variable],dim='time')

# Merge the Datasets together:
tempo_data_no2 = xr.merge([data_dictionary[variable] for variable in variables_to_keep_and_rename.keys()])

# Rename the variables
tempo_data_no2 = tempo_data_no2.rename({variable.split('/')[1]:variables_to_keep_and_rename[variable] for variable in variables_to_keep_and_rename.keys()})

# Examine the result:
tempo_data_no2
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:                          (longitude: 4650, latitude: 150, time: 80)
# Coordinates:
#   * longitude                        (longitude) float32 19kB -106.0 ... -13.01
#   * latitude                         (latitude) float32 600B 38.01 ... 40.99
#   * time                             (time) datetime64[ns] 640B 2024-07-27T10...
# Data variables:
#     no2_vertical_column_troposphere  (time, latitude, longitude) float64 446MB ...
#     no2_qc_flag                      (time, latitude, longitude) float32 223MB ...
#     no2_sza                          (time, latitude, longitude) float32 223MB ...
#     no2_cloud_fraction               (time, latitude, longitude) float32 223MB ...
# Attributes:
#     long_name:  troposphere nitrogen dioxide vertical column
#     units:      molecules/cm^2

# %% [markdown]
# *Apply quality control*
#
# <details>
#
# For this exercise, we will accept Suspect data, and also filter by Solar Zenith Angle (accepting values less than 80) and Cloud Fraction (accepting values less than 0.2)
#
# *Hint:* TEMPO quality flags are:
#
# * `0` = Normal quality (use for analysis)
#
# * `1` = Suspect quality (use with caution)
#
# * `2` = Bad quality (exclude from analysis)
#
# </details>

# %%
filter_qa = tempo_data_no2['no2_qc_flag'] <= 1
filter_sza = tempo_data_no2['no2_sza'] < 80
filter_cf = tempo_data_no2['no2_cloud_fraction'] < 0.2

tempo_data_no2_filtered = tempo_data_no2.where(filter_qa & filter_sza & filter_cf).squeeze()

# %% [markdown]
# ## Get TEMPO Level-3 HCHO Data
#
# The below code is copied from previous examples of downloading TEMPO data. You will use it to download TEMPO Level-3 HCHO data for a region and time period of inerest.
#
# **Region of Interest**: Colorado Front Range (latitude 38 to 41, longitude -106 to -103)
#
# **Time of Interest**: July 27 to 31, 2024
#
# *Instructions*
#
# * Modify the code in the next cells to download the TEMPO Level-3 HCHO data product for the region and time period of interest.
#
# * Run the cells in sequence to download the desired TEMPO data.
#
# <details>
#
# *Hint*: You will need to modify the `RoI`, `Collection id`, `start` and `stop` times.
#
# *Hint*: Use [Earthdata Search](https://search.earthdata.nasa.gov/search) to get the Collection id.
#
# </details>

# %% [markdown]
# *Build the request*

# %%
# Structure the request:
request_hcho = Request(
    collection=Collection(id='C2930761273-LARC_CLOUD'),
    temporal={
        'start': dt.datetime(2024, 7, 27, 7,0,0),
        'stop': dt.datetime(2024, 7, 31, 23, 0, 0)
    },
    spatial=BBox(RoI[0], RoI[1], RoI[2], RoI[3]),
)

# Check the request is valid:
request_hcho.is_valid()
# Out:
# True

# %% [markdown]
# *Submit and monitor the request*

# %%
job_id_hcho = harmony_client.submit(request_hcho)
print(f"jobID = {job_id_hcho}")

harmony_client.wait_for_processing(job_id_hcho, show_progress=True)
# Out:
# jobID = 4d1e4d42-c943-443d-8edd-1841612941a6
#  [ Processing: 100% ] |###################################################| [|]

# %% [markdown]
# *Download the results*

# %%
results_hcho = harmony_client.download_all(job_id_hcho, directory=download_dir)
all_results_stored_hcho = [f.result() for f in results_hcho]

print(f"Number of files: {len(all_results_stored_hcho)}")
# Out:
# /root/tempo_data_ozone_precursor_exercise/106864600_TEMPO_HCHO_L3_V03_20240727T103122Z_S001_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864603_TEMPO_HCHO_L3_V03_20240727T123137Z_S004_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864616_TEMPO_HCHO_L3_V03_20240728T005202Z_S017_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864613_TEMPO_HCHO_L3_V03_20240727T225147Z_S014_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864625_TEMPO_HCHO_L3_V03_20240728T165204Z_S009_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864615_TEMPO_HCHO_L3_V03_20240728T001157Z_S016_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864651_TEMPO_HCHO_L3_V03_20240730T001230Z_S017_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864650_TEMPO_HCHO_L3_V03_20240729T233225Z_S016_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864620_TEMPO_HCHO_L3_V03_20240728T123154Z_S004_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864619_TEMPO_HCHO_L3_V03_20240728T115149Z_S003_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864601_TEMPO_HCHO_L3_V03_20240727T111127Z_S002_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864638_TEMPO_HCHO_L3_V03_20240729T123210Z_S004_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864636_TEMPO_HCHO_L3_V03_20240729T111200Z_S002_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864626_TEMPO_HCHO_L3_V03_20240728T175204Z_S010_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864647_TEMPO_HCHO_L3_V03_20240729T205220Z_S013_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864608_TEMPO_HCHO_L3_V03_20240727T175147Z_S009_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864607_TEMPO_HCHO_L3_V03_20240727T171416Z_S008_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864640_TEMPO_HCHO_L3_V03_20240729T135220Z_S006_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864649_TEMPO_HCHO_L3_V03_20240729T225220Z_S015_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864605_TEMPO_HCHO_L3_V03_20240727T135147Z_S006_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864632_TEMPO_HCHO_L3_V03_20240728T233209Z_S016_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864648_TEMPO_HCHO_L3_V03_20240729T215220Z_S014_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864653_TEMPO_HCHO_L3_V03_20240730T103211Z_S001_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864652_TEMPO_HCHO_L3_V03_20240730T005235Z_S018_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864631_TEMPO_HCHO_L3_V03_20240728T225204Z_S015_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864645_TEMPO_HCHO_L3_V03_20240729T185220Z_S011_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864635_TEMPO_HCHO_L3_V03_20240729T103155Z_S001_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864602_TEMPO_HCHO_L3_V03_20240727T115132Z_S003_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864630_TEMPO_HCHO_L3_V03_20240728T215204Z_S014_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864637_TEMPO_HCHO_L3_V03_20240729T115205Z_S003_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864614_TEMPO_HCHO_L3_V03_20240727T233152Z_S015_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864617_TEMPO_HCHO_L3_V03_20240728T103139Z_S001_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864627_TEMPO_HCHO_L3_V03_20240728T185204Z_S011_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864604_TEMPO_HCHO_L3_V03_20240727T131142Z_S005_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864609_TEMPO_HCHO_L3_V03_20240727T185147Z_S010_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864612_TEMPO_HCHO_L3_V03_20240727T215147Z_S013_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864629_TEMPO_HCHO_L3_V03_20240728T205204Z_S013_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864628_TEMPO_HCHO_L3_V03_20240728T195204Z_S012_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864639_TEMPO_HCHO_L3_V03_20240729T131215Z_S005_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864623_TEMPO_HCHO_L3_V03_20240728T145204Z_S007_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864622_TEMPO_HCHO_L3_V03_20240728T135204Z_S006_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864644_TEMPO_HCHO_L3_V03_20240729T175220Z_S010_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864641_TEMPO_HCHO_L3_V03_20240729T145220Z_S007_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864646_TEMPO_HCHO_L3_V03_20240729T195220Z_S012_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864634_TEMPO_HCHO_L3_V03_20240729T005219Z_S018_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864624_TEMPO_HCHO_L3_V03_20240728T155204Z_S008_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864633_TEMPO_HCHO_L3_V03_20240729T001214Z_S017_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864643_TEMPO_HCHO_L3_V03_20240729T165220Z_S009_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864618_TEMPO_HCHO_L3_V03_20240728T111144Z_S002_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864642_TEMPO_HCHO_L3_V03_20240729T155220Z_S008_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864610_TEMPO_HCHO_L3_V03_20240727T195147Z_S011_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864621_TEMPO_HCHO_L3_V03_20240728T131159Z_S005_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864611_TEMPO_HCHO_L3_V03_20240727T205147Z_S012_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864606_TEMPO_HCHO_L3_V03_20240727T145148Z_S007_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864654_TEMPO_HCHO_L3_V03_20240730T111216Z_S002_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864656_TEMPO_HCHO_L3_V03_20240730T123226Z_S004_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864661_TEMPO_HCHO_L3_V03_20240730T165236Z_S009_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864659_TEMPO_HCHO_L3_V03_20240730T145236Z_S007_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864657_TEMPO_HCHO_L3_V03_20240730T131231Z_S005_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864655_TEMPO_HCHO_L3_V03_20240730T115221Z_S003_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864665_TEMPO_HCHO_L3_V03_20240730T205236Z_S013_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864664_TEMPO_HCHO_L3_V03_20240730T195236Z_S012_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864663_TEMPO_HCHO_L3_V03_20240730T185236Z_S011_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864658_TEMPO_HCHO_L3_V03_20240730T135236Z_S006_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864660_TEMPO_HCHO_L3_V03_20240730T155236Z_S008_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864662_TEMPO_HCHO_L3_V03_20240730T175236Z_S010_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864679_TEMPO_HCHO_L3_V03_20240731T225252Z_S015_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864666_TEMPO_HCHO_L3_V03_20240731T010539Z_S014_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864669_TEMPO_HCHO_L3_V03_20240731T115237Z_S003_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864676_TEMPO_HCHO_L3_V03_20240731T195252Z_S012_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864667_TEMPO_HCHO_L3_V03_20240731T103227Z_S001_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864668_TEMPO_HCHO_L3_V03_20240731T111232Z_S002_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864671_TEMPO_HCHO_L3_V03_20240731T131247Z_S005_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864670_TEMPO_HCHO_L3_V03_20240731T123242Z_S004_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864678_TEMPO_HCHO_L3_V03_20240731T215252Z_S014_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864672_TEMPO_HCHO_L3_V03_20240731T135252Z_S006_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864677_TEMPO_HCHO_L3_V03_20240731T205252Z_S013_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864673_TEMPO_HCHO_L3_V03_20240731T165252Z_S009_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864675_TEMPO_HCHO_L3_V03_20240731T185252Z_S011_subsetted.nc4
# /root/tempo_data_ozone_precursor_exercise/106864674_TEMPO_HCHO_L3_V03_20240731T175252Z_S010_subsetted.nc4
# Number of files: 80

# %% [markdown]
# *Open the files and combine into a single Dataset*

# %%
# Define which variables to keep and rename:
variables_to_keep_and_rename = {'product/vertical_column':'hcho_vertical_column',
                                'product/main_data_quality_flag':'hcho_qc_flag',
                                'geolocation/solar_zenith_angle':'hcho_sza',
                                'support_data/eff_cloud_fraction':'hcho_cloud_fraction'
                                }

# Create a dictionary to store the data:
data_dictionary = {variable:[] for variable in variables_to_keep_and_rename.keys()}

# Loop through the result files:
for result_file in sorted(all_results_stored_hcho):
    # Loop throuch variables:
    for variable in variables_to_keep_and_rename.keys():
        # For each file and variable, add the data from that file to the appropriate list in the dictionary:
        data_dictionary[variable] += [xr.open_datatree(result_file)[variable]]

# Concatenate each list into a Dataset along the time dimenion:
for variable in variables_to_keep_and_rename.keys():
    data_dictionary[variable] = xr.concat(data_dictionary[variable],dim='time')

# Merge the Datasets together:
tempo_data_hcho = xr.merge([data_dictionary[variable] for variable in variables_to_keep_and_rename.keys()])

# Rename the variables
tempo_data_hcho = tempo_data_hcho.rename({variable.split('/')[1]:variables_to_keep_and_rename[variable] for variable in variables_to_keep_and_rename.keys()})

# Examine the result:
tempo_data_hcho
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:               (longitude: 4650, latitude: 150, time: 80)
# Coordinates:
#   * longitude             (longitude) float32 19kB -106.0 -106.0 ... -13.01
#   * latitude              (latitude) float32 600B 38.01 38.03 ... 40.97 40.99
#   * time                  (time) datetime64[ns] 640B 2024-07-27T10:31:40.1544...
# Data variables:
#     hcho_vertical_column  (time, latitude, longitude) float64 446MB nan ... nan
#     hcho_qc_flag          (time, latitude, longitude) float32 223MB nan ... nan
#     hcho_sza              (time, latitude, longitude) float32 223MB nan ... nan
#     hcho_cloud_fraction   (time, latitude, longitude) float32 223MB nan ... nan
# Attributes:
#     long_name:  formaldehyde vertical column
#     comment:    formaldehyde vertical column determined from fitted slant col...
#     units:      molecules/cm^2

# %% [markdown]
# *Apply quality control*
#
# <details>
#
# For this exercise, we will accept Suspect data, and also filter by Solar Zenith Angle (accepting values less than 80) and Cloud Fraction (accepting values less than 0.2)
#
# *Hint:* TEMPO quality flags are:
#
# * `0` = Normal quality (use for analysis)
#
# * `1` = Suspect quality (use with caution)
#
# * `2` = Bad quality (exclude from analysis)
#
# </details>

# %%
filter_qa = tempo_data_hcho['hcho_qc_flag'] <= 1
filter_sza = tempo_data_hcho['hcho_sza'] < 80
filter_cf = tempo_data_hcho['hcho_cloud_fraction'] < 0.2

tempo_data_hcho_filtered = tempo_data_hcho.where(filter_qa & filter_sza & filter_cf).squeeze()

# %% [markdown]
# ## Combine into a single TEMPO Dataset
#
# To facilitate analysis, it will help if all the data are in one dataset.
#
# *Instructions*
#
# * Write code to merge the quality-controlled datasets together into one.
#
# * Write code to merge the original datasets (without quality control filters applied) into one.
#
# <details>
#
# *Hint*: To merge datasets together, use the following code example:
#
# ```
# merged_dataset = xr.merge([dataset_1,dataset_2])
# ```
#
#
# </details>

# %%
# WRITE YOUR CODE HERE

tempo_data_filtered = xr.merge([tempo_data_no2_filtered,tempo_data_hcho_filtered])

tempo_data_filtered
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:                          (time: 80, latitude: 150, longitude: 4650)
# Coordinates:
#   * longitude                        (longitude) float32 19kB -106.0 ... -13.01
#   * latitude                         (latitude) float32 600B 38.01 ... 40.99
#   * time                             (time) datetime64[ns] 640B 2024-07-27T10...
# Data variables:
#     no2_vertical_column_troposphere  (time, latitude, longitude) float64 446MB ...
#     no2_qc_flag                      (time, latitude, longitude) float32 223MB ...
#     no2_sza                          (time, latitude, longitude) float32 223MB ...
#     no2_cloud_fraction               (time, latitude, longitude) float32 223MB ...
#     hcho_vertical_column             (time, latitude, longitude) float64 446MB ...
#     hcho_qc_flag                     (time, latitude, longitude) float32 223MB ...
#     hcho_sza                         (time, latitude, longitude) float32 223MB ...
#     hcho_cloud_fraction              (time, latitude, longitude) float32 223MB ...
# Attributes:
#     long_name:  troposphere nitrogen dioxide vertical column
#     units:      molecules/cm^2

# %% [markdown]
# # Plotting NO2 and HCHO for different times and time intervals

# %% [markdown]
# We will now create plots of NO2 and HCHO for the event, examining the effects of changing the averaging time and cloud fraction filtering.

# %% [markdown]
# *Instructuions*
#
# * Run the cell below to define the data projection and the mapping function.

# %%
data_proj = ccrs.PlateCarree()

def make_nice_map(axis):
    axis.add_feature(cfeature.STATES.with_scale('50m'), edgecolor="black", linewidth=0.5)
    roads = cfeature.NaturalEarthFeature(
        category="cultural",
        name="roads",
        scale="10m",
        facecolor="none",
    )
    axis.add_feature(roads, linestyle="--", edgecolor="grey", linewidth=0.5)
    axis.coastlines(resolution="50m", color="black", linewidth=1.0)

    axis.set_extent([RoI[0], RoI[2], RoI[1], RoI[3]], crs=data_proj)
    grid = axis.gridlines(draw_labels=["left", "bottom"], dms=True)
    grid.xformatter = LONGITUDE_FORMATTER
    grid.yformatter = LATITUDE_FORMATTER

# %% [markdown]
# ## Plot Datasets for a Single Timestamp
#
# The code below is taken from earlier plotting examples, with slight modifications. It is meant to plot the NO2 and HCHO data side-by-side, for a single time.
#
# *Instructions*
#
# * Identify where the code is getting its data inputs for NO2 and HCHO. Modify this to the filtered dataset you created earlier.
#
# * Run the cell and check the output.
#
# * Try picking different timestamps to plot and examining the output.
#
# <details>
#
# *Hint*: The code assumes the data are coming from a `tempo_data_filtered` Dataset.
#
# </details>

# %%
# Choose a timestamp to plot:
timestamp_local = pd.Timestamp('2024-07-29 14:30:00',tz='America/Denver')

# Convert the timestamp from local time to UTC:
timestamp_utc = timestamp_local.tz_convert(tz='UTC').to_datetime64()

# Select the data to plot:
data_to_plot_no2 = tempo_data_filtered['no2_vertical_column_troposphere'].sel(time=timestamp_utc,method='nearest')
data_to_plot_hcho = tempo_data_filtered['hcho_vertical_column'].sel(time=timestamp_utc,method='nearest')

# Plot the data on a map:
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5), subplot_kw={"projection": data_proj})

make_nice_map(ax[0])

data_to_plot_no2.plot(
    ax=ax[0], # axis to add plot to
    cmap=plt.get_cmap('Purples'), # color scale
    vmin=0, # minimum value
    vmax=20e15, # maximum value
    cbar_kwargs={'label':'Tropospheric Column $NO_2$ [$molecules/cm^2$]'} # set colorbar label,
)
ax[0].set_xlim((-106,-103))

make_nice_map(ax[1])

data_to_plot_hcho.plot(
    ax=ax[1], # axis to add plot to
    cmap=plt.get_cmap('Oranges'), # color scale
    vmin=0, # minimum value
    vmax=20e15, # maximum value
    cbar_kwargs={'label':'Tropospheric Column $HCHO$ [$molecules/cm^2$]'} # set colorbar label
)
ax[1].set_xlim((-106,-103))

fig.suptitle(timestamp_local)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Try Changing the Quality Control
#
# In the above plots, some of the densest parts of the plumes are missing. Aggressively filtering based on the cloud fraction can also remove thick smoke. To reduce this issue, we will apply a less strict quality control filter for the effective cloud fraction.
#
# *Instructions*
#
# * Revisit the combined dataset without filtering you created above.
#
# * Apply new quality control filters to that dataset to create a new filtered dataset. Specifically, we will accept Suspect data, filter by Solar Zenith Angle (accepting values less than 80), and Cloud Fraction (now accepting values less than 0.5, rahter than 0.2).
#
# <details>
#
# *Hint*: You can create a dataset which acts as a binary filtering mask by setting it equal to a logical expression, such as an inequality. For example:
#
# ```
# binary_mask = data <= threshold
# ```
#
# `binary_mask` will have value `True` wherever the values in `data` are less than or equal to `threshold`. You can use this to mask out data from the dataset. For example:
#
# ```
# maksed_data = data.where(mask).squeeze()
# ```
#
# `masked_data` will contain the values in `data` where the `mask` is `True`, and will be `NaN` otherwise.
#
# *Hint*: You can use the logical expression `&` to combine multiple binary masks. For example:
#
# ```
# data_masked_by_a_and_b = data.where(mask_a & mask_b).squeeze()
# ```
#
# *Hint*: Revisit the quality controls applied when the data were first downloaded for additional examples.
#
# </details>

# %%
# WRITE YOUR CODE HERE

# %% [markdown]
# Now, we will re-plot the figures for a single timestamp.
#
# *Instructions*
#
# * Identify where the code is getting its data inputs for NO2 and HCHO. Modify this to the newly filtered dataset you just created.
#
# * Run the cell and check the output.
#
# * Try picking different timestamps to plot and examining the output.
#
# <details>
#
# *Hint*: The code assumes the data are coming from a `tempo_data_refiltered` Dataset.
#
# </details>

# %%
# Choose a timestamp to plot:
timestamp_local = pd.Timestamp('2024-07-29 14:30:00',tz='America/Denver')

# Convert the timestamp from local time to UTC:
timestamp_utc = timestamp_local.tz_convert(tz='UTC').to_datetime64()

# Select the data to plot:
data_to_plot_no2 = tempo_data_refiltered['no2_vertical_column_troposphere'].sel(time=timestamp_utc,method='nearest')
data_to_plot_hcho = tempo_data_refiltered['hcho_vertical_column'].sel(time=timestamp_utc,method='nearest')

# Plot the data on a map:
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5), subplot_kw={"projection": data_proj})

make_nice_map(ax[0])

data_to_plot_no2.plot(
    ax=ax[0], # axis to add plot to
    cmap=plt.get_cmap('Purples'), # color scale
    vmin=0, # minimum value
    vmax=20e15, # maximum value
    cbar_kwargs={'label':'Tropospheric Column $NO_2$ [$molecules/cm^2$]'} # set colorbar label
)

make_nice_map(ax[1])

data_to_plot_hcho.plot(
    ax=ax[1], # axis to add plot to
    cmap=plt.get_cmap('Oranges'), # color scale
    vmin=0, # minimum value
    vmax=20e15, # maximum value
    cbar_kwargs={'label':'Tropospheric Column $HCHO$ [$molecules/cm^2$]'} # set colorbar label
)

fig.suptitle(timestamp_local)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plot Datasets Averaged for Multiple Timestamps
#
# Plots at single timesteps can be noisy, and have missing data. To reduce some of these data gaps and smooth out noise, we can average across multiple timesteps.
#
# *Instructions*
#
# * Write code to define the `data_to_plot_no2` and `data_to_plot_hcho` variables.
#
#   * `data_to_plot_no2` should be the average of your newly filtered NO2 tropospheric column data between `timestamp_utc_start` and `timestamp_utc_stop`
#
#   * `data_to_plot_hcho` should be the average of your newly filtered HCHO column data between `timestamp_utc_start` and `timestamp_utc_stop`
#
# * Run the cell and check the output.
#
# * Try picking different starting and ending times for the averaging period and examining the output.
#
# <details>
#
# *Hint*: This example code will average the values of `data` between `start_time` and `stop_time`:
#
# ```
# time_average_data = data.sel(time=slice(start_time,stop_time)).mean('time')
# ```
#
#
# </details>

# %%
# Choose a timestamp to plot:
timestamp_local_start = pd.Timestamp('2024-07-29 00:00:00',tz='America/Denver')
timestamp_local_stop = pd.Timestamp('2024-07-30 23:59:59',tz='America/Denver')

# Convert the timestamp from local time to UTC:
timestamp_utc_start = timestamp_local_start.tz_convert(tz='UTC').to_datetime64()
timestamp_utc_stop = timestamp_local_stop.tz_convert(tz='UTC').to_datetime64()

# Select the data to plot:
data_to_plot_no2 = # WRITE YOUR CODE HERE
data_to_plot_hcho = # WRITE YOUR CODE HERE

# Plot the data on a map:
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5), subplot_kw={"projection": data_proj})

make_nice_map(ax[0])

data_to_plot_no2.plot(
    ax=ax[0], # axis to add plot to
    cmap=plt.get_cmap('Purples'), # color scale
    vmin=0, # minimum value
    vmax=20e15, # maximum value
    cbar_kwargs={'label':'Tropospheric Column $NO_2$ [$molecules/cm^2$]'} # set colorbar label
)

make_nice_map(ax[1])

data_to_plot_hcho.plot(
    ax=ax[1], # axis to add plot to
    cmap=plt.get_cmap('Oranges'), # color scale
    vmin=0, # minimum value
    vmax=20e15, # maximum value
    cbar_kwargs={'label':'Tropospheric Column $HCHO$ [$molecules/cm^2$]'} # set colorbar label
)

fig.suptitle(f'{timestamp_local_start} to {timestamp_local_stop}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Create Daily-Average Plots
#
# Plots averaged over about a day are relatively smooth and complete. We will plot a series of daily-averaged maps of NO2 and HCHO.
#
# *Instructions*
#
# * The code below has been set up to plot daily averages for a sequence of days, defined by `days_to_plot`. Check that `days_to_plot` starts on the correct day and has the correct number of days (`periods`) for the time interval of your dataset.
#
# * Copy the code you created above to define the `data_to_plot_no2` and `data_to_plot_hcho` variables.
#
# * Run the cell and check the outputs.

# %%
# Define a sequence of days to plot:
days_to_plot = pd.date_range("2024-07-27", periods=4, freq="D", tz='America/Denver')

# Create the figure
fig, ax = plt.subplots(nrows=len(days_to_plot), ncols=2, figsize=(10, 5*len(days_to_plot)), subplot_kw={"projection": data_proj})

for day_index,day_timestamp in enumerate(days_to_plot):
    # Choose a timestamp to plot:
    timestamp_local_start = day_timestamp
    timestamp_local_stop = day_timestamp + pd.Timedelta(days=1)

    # Convert the timestamp from local time to UTC:
    timestamp_utc_start = timestamp_local_start.tz_convert(tz='UTC').to_datetime64()
    timestamp_utc_stop = timestamp_local_stop.tz_convert(tz='UTC').to_datetime64()

    # Select the data to plot:
    data_to_plot_no2 = # WRITE YOUR CODE HERE
    data_to_plot_hcho = # WRITE YOUR CODE HERE

    # Plot the data on a map:
    make_nice_map(ax[day_index,0])

    data_to_plot_no2.plot(
        ax=ax[day_index,0], # axis to add plot to
        cmap=plt.get_cmap('Purples'), # color scale
        vmin=0, # minimum value
        vmax=20e15, # maximum value
        cbar_kwargs={'label':'Tropospheric Column $NO_2$ [$molecules/cm^2$]'} # set colorbar label
    )

    ax[day_index,0].set_title(timestamp_local_start.date())

    make_nice_map(ax[day_index,1])

    data_to_plot_hcho.plot(
        ax=ax[day_index,1], # axis to add plot to
        cmap=plt.get_cmap('Oranges'), # color scale
        vmin=0, # minimum value
        vmax=20e15, # maximum value
        cbar_kwargs={'label':'Tropospheric Column $HCHO$ [$molecules/cm^2$]'} # set colorbar label
    )

    ax[day_index,1].set_title(timestamp_local_start.date())

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analyse the Formaldehyde-to-NO2 Ratios
#
# Finally, will can assess the Formaldehyde-to-NO2 ratios as a potential indicator of the causes of ozone formation. The code below is similar to the above, and is intended to plot daily averages of a variable `data_to_plot_fnr`, which you need to define.
#
# *Instructions*
#
# * Copy the code you created above to define the `data_to_plot_no2` and `data_to_plot_hcho` variables.
#
# * Add code to define `data_to_plot_fnr` as the ratio of `data_to_plot_hcho` and `data_to_plot_no2`.
#
# * Run the cell and check the outputs.
#
# <details>
#
# *Hint*: The formula for a ratio in python is: `ratio = numerator/denominator`

# %%
# Define a sequence of days to plot:
days_to_plot = pd.date_range("2024-07-27", periods=4, freq="D", tz='America/Denver')

# Create the figure
fig, ax = plt.subplots(nrows=len(days_to_plot), ncols=1, figsize=(7, 5*len(days_to_plot)), subplot_kw={"projection": data_proj})

for day_index,day_timestamp in enumerate(days_to_plot):
    # Choose a timestamp to plot:
    timestamp_local_start = day_timestamp
    timestamp_local_stop = day_timestamp + pd.Timedelta(days=1)

    # Convert the timestamp from local time to UTC:
    timestamp_utc_start = timestamp_local_start.tz_convert(tz='UTC').to_datetime64()
    timestamp_utc_stop = timestamp_local_stop.tz_convert(tz='UTC').to_datetime64()

    # Select the data to plot:
    data_to_plot_no2 = # WRITE YOUR CODE HERE
    data_to_plot_hcho = # WRITE YOUR CODE HERE
    data_to_plot_fnr = # WRITE YOUR CODE HERE

    # Plot the data on a map:
    make_nice_map(ax[day_index])

    data_to_plot_fnr.plot(
        ax=ax[day_index], # axis to add plot to
        cmap=plt.get_cmap('PuOr_r'), # color scale
        vmin=1, # minimum value
        vmax=11, # maximum value
        cbar_kwargs={'label':'$HCHO$ / $NO_2$'} # set colorbar label
    )

    ax[day_index].set_title(timestamp_local_start.date())

plt.tight_layout()
plt.show()

# %% [markdown]
# # Bonus: Compare with AirNow Ozone Monitor Data
#
# We can add the surface ozone monitor data into our plots for additional context.

# %% [markdown]
# ## Use pyrsig to download AirNow ozone
#
# We will use the [pyrsig package](https://barronh.github.io/pyrsig/) to easily bring the AirNow ozone data into python. Below is a template for how a query is structured and submitted to pyrsig. The result will be a data table with the ozone data, timestamps, and station information.
#
# *Instructions*
#
# * Modify the template to have the approrpiate start end and dates.
#
# * Modify the template to have the appropriate bounding box for the region of interest.
#
# * Run the cell to examine the output table.

# %%
# Define the query for pyrisg:
api = pyrsig.RsigApi(bdate="2024-07-27", # start date of the query, in the format "YYYY-MM-DD"
                     edate="2024-07-31", # end date of the query, in the format "YYY-MM-DD"
                     bbox=(RoI[0],RoI[1],RoI[2],RoI[3]), # bounding box for the query, in the format (minimum_longitude,minimum_latitude,maximum_longitude,maximum_latitude)
                     workdir=download_dir, # temporary directory to store the downloaded data
                     gridfit=True) # data are not being re-aligned to a grid
airnowkey = "airnow.ozone" # this is the pyrsig code to specify ozone data from AirNow

# Execute the query to download the data:
airnow_data = api.to_dataframe(airnowkey, unit_keys=False, parse_dates=True)

# Examine the resulting table:
airnow_data

# %% [markdown]
# ## Map Comparison Plot
#
# Finally, we will overlay ozone monitor averages onto an Formaldehyde-to-NO2 ratio map. The code example below should generate this plot, but again, it assumes the data are in specifically named datasets which might not exist in your run of the code.
#
# *Instructions*
#
# * Examine the code and see if you can understand what is happening in each part.
#
# * Try to run the code below, troubleshooting any errors you encounter.
#
# * Try changing the axis limits on the ozone plot colorbar.
#
# <details>
#
# *Hint*: If youn are getting errors, try copying subsets of the code into a new cell to run it incrementally, and see where the errors are coming from. Put the name of a variable in a cell by itself and run that cell to see what the variable looks like.

# %%
# Define a sequence of days to plot:
days_to_plot = pd.date_range("2024-07-27", periods=4, freq="D", tz='America/Denver')

# Create the figure
fig, ax = plt.subplots(nrows=len(days_to_plot), ncols=1, figsize=(10, 5*len(days_to_plot)), subplot_kw={"projection": data_proj})

for day_index,day_timestamp in enumerate(days_to_plot):
    # Choose a timestamp to plot:
    timestamp_local_start = day_timestamp
    timestamp_local_stop = day_timestamp + pd.Timedelta(days=1)

    # Convert the timestamp from local time to UTC:
    timestamp_utc_start = timestamp_local_start.tz_convert(tz='UTC').to_datetime64()
    timestamp_utc_stop = timestamp_local_stop.tz_convert(tz='UTC').to_datetime64()

    # Select the data to plot:
    data_to_plot_no2 = tempo_data_refiltered['no2_vertical_column_troposphere'].sel(time=slice(timestamp_utc_start,timestamp_utc_stop)).mean('time')
    data_to_plot_hcho = tempo_data_refiltered['hcho_vertical_column'].sel(time=slice(timestamp_utc_start,timestamp_utc_stop)).mean('time')
    data_to_plot_fnr = data_to_plot_hcho/data_to_plot_no2

    # Subset the AirNow ozone data to plot:
    airnow_data_subset = airnow_data.where((airnow_data['time'] >= pd.Timestamp(timestamp_utc_start,tz='UTC')) & (airnow_data['time'] < pd.Timestamp(timestamp_utc_stop,tz='UTC'))).dropna(how='all')

    # Compute the average:
    average_ozone_to_plot = airnow_data_subset[['STATION','LATITUDE','LONGITUDE','ozone']].groupby('STATION').mean()

    # Plot the data on a map:
    make_nice_map(ax[day_index])

    ratio_plot = data_to_plot_fnr.plot(
        ax=ax[day_index], # axis to add plot to
        cmap=plt.get_cmap('PuOr_r'), # color scale
        vmin=1, # minimum value
        vmax=11, # maximum value
        add_colorbar=False
    )

    colorbar_ratio = plt.colorbar(ratio_plot)
    colorbar_ratio.set_label('HCHO / $NO_2$')

    ozone_plot = ax[day_index].scatter(average_ozone_to_plot['LONGITUDE'],
                            average_ozone_to_plot['LATITUDE'],
                            s=100,
                            c=average_ozone_to_plot['ozone'],
                            cmap=plt.get_cmap('Greens'),
                            vmin=40,
                            vmax=80,
                            edgecolors='black')

    colorbar_ozone = plt.colorbar(ozone_plot)
    colorbar_ozone.set_label('Ozone [ppb]')

    ax[day_index].set_title(timestamp_local_start.date())

plt.tight_layout()
plt.show()
